# %%
class Node:
  def __init__(self,ID,name,next):
    self.ID=ID
    self.name=name
    self.next=next

# %%
class Marathon:
  def __init__(self):
    self.head=None

  def register(self,arr):
    #remove pass and start your code from here
    temp = None
    self.ID=0
    for i in range(len(arr)):
      n= Node(self.ID, arr[i], temp)
      temp= n
      self.ID += 1
    self.head= n
    while n!=None:
      print(self.ID, n.name, end = ' ')
      n= n.next
      self.ID-=1
    return n
  def addFarahBrothers(self):
    # remove pass and start your code from here
    temp = None
    self.ID=0
    for i in range(len(arr)):
      n= Node(self.ID, arr[i], temp)
      temp= n
      self.ID += 1
    save = self.ID
    self.head= n
    while n!=None:
      print(self.ID, n.name, end = ' ')
      n= n.next
      self.ID-=1
    temp = self.head
    while temp!= None:
      if temp == 'Sakib':
        temp.next == 'Mo Farah'
        temp.next.next== 'Hassan'
      temp= temp.next
    print(self.ID,temp.name, end = ' ')
    # pass



  def makeDoubly(self):
    #remove pass and start your code from here
    doubly = Node(None)
    temp2 = self.head
    while temp2!= None:
      doubly.next=temp2
      temp2.next= doubly
      temp2 = temp2.next
    return doubly

# %%
import numpy as np
#Driver code
arr=np.array(["Kamal","Jamal","Rakib","Sakib","Farah","Jordan","Mike"])
m1=Marathon()
m1.register(arr)
m1.addFarahBrothers()
m1.makeDoubly()
# Out:
# 7 Mike 6 Jordan 5 Farah 4 Sakib 3 Rakib 2 Jamal 1 Kamal
