# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  #To Do
  if root is None:
    return None
  root.left, root.right = root.right, root.left
  convert_mirror(root.left)
  convert_mirror(root.right)
  return root


#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root,i=0,dit={}):
  #To Do
  if root==None:
    return dit

  elif i not in dit or (root.elem < dit[i]):
    dit[i] = root.elem

  smallest_level(root.left, i+1,dit)
  smallest_level(root.right,i+1,dit)

  return dit

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):
  #To Do
  if root==None:
    return None
  if root.elem<x.elem:
    temp=inorder_predecessor(root.right, x)
    if temp!=None:
      return temp
    else:
      return root
  else:
      return inorder_predecessor(root.left, x)

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):
  #To Do
  if root is None:
    return None
  if x<root.elem and y<root.elem:
    return LCA(root.left, x, y)
  if x>root.elem and y>root.elem:
    return LCA(root.right, x, y)
  return root

#DRIVER CODE
#Write by yourself from the given tree
#check all the sample inputs given
root = BTNode(15)
root.left = BTNode(10)
root.right = BTNode(25)
root.left.left = BTNode(8)
root.left.right = BTNode(12)
root.right.left = BTNode(20)
root.right.right = BTNode(30)
root.left.left.left = BTNode(6)
root.left.left.right = BTNode(9)
root.right.left.left = BTNode(18)
root.right.left.right = BTNode(22)


lca_node = LCA(root, 6, 12)
print(f"LCA(6, 12) = {lca_node.elem if lca_node else 'do not exist'}")

lca_node = LCA(root, 20, 6)
print(f"LCA(20, 6) = {lca_node.elem if lca_node else 'do not exist'}")

lca_node = LCA(root, 18, 22)
print(f"LCA(18, 22) = {lca_node.elem if lca_node else 'do not exist'}")

lca_node = LCA(root, 20, 25)
print(f"LCA(20, 25) = {lca_node.elem if lca_node else 'do not exist'}")

lca_node = LCA(root, 10, 12)
print(f"LCA(10, 12) = {lca_node.elem if lca_node else 'do not exist'}")
# Out:
# LCA(6, 12) = 10
# LCA(20, 6) = 15
# LCA(18, 22) = 20
# LCA(20, 25) = 25
# LCA(10, 12) = 10

# %% [markdown]
# Task 5

# %%
def sumTree(root):
  # pass
  def helper(node, level):
    if node is None:
        return 0
    if level == 0:
        return node.elem
    left_sum = helper(node.left, level - 1)
    right_sum = helper(node.right, level - 1)
    return (left_sum + right_sum) % (level + 1)

    total_sum = 0
    max_level = find_max_level(root)
    for level in range(max_level + 1):
        total_sum += helper(root, level)
    return total_sum

def find_max_level(node):
    if node is None:
        return -1
    return max(find_max_level(node.left), find_max_level(node.right)) + 1



  # To DO
  #you can declare as many helper function with extra parameters as you need .
  #You can not modify the parameters of sumTree or modify any part of the given code.

# %%
#Driver Code
#Input 1
root1 = BTNode(9)
node2 = BTNode(4)
node3 = BTNode(5)
node4 = BTNode(18)
node5 = BTNode(14)
node6 = BTNode(3)
node7 = BTNode(54)
node8 = BTNode(12)
node9 = BTNode(8)
node10 = BTNode(91)
node11 = BTNode(56)

root1.left = node2
root1.right = node3

node2.left = node4

node3.left = node5
node3.right = node6

node4.left = node7
node4.right = node8

node5.left = node9

node8.left = node10
node8.right = node11

print(sumTree(root1)) #This should print 15
# Out:
# 15

# %% [markdown]
# Task 6

# %%
def swap_child(root, level, M):
  #To Do
  if root is None:
      return

  if level >= M:
      root.left, root.right = root.right, root.left

  swap_child(root.left, level + 1, M)
  swap_child(root.right, level + 1, M)

def inorder(root):
  if root:
    inorder(root.left)
    print(root.elem, end=' ')
    inorder(root.right)


#Driver Code
root=BTNode('A')
#Write other nodes by yourself from the given tree of Doc File


print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)   #Given Tree Inorder Traversal: G D H B I E A C J F
print()

root2 = swap_child(root, 0, 2)
print('Swapped Tree Inorder Traversal: ', end = ' ')
inorder(root2)  #Swapped Tree Inorder Traversal: J F C A I E B G D H
# Out:
# Given Tree Inorder Traversal:  A
# Swapped Tree Inorder Traversal:

# %% [markdown]
# Task 7

# %%
def sum_of_nodes(node):
  if node is None:
    return 0
  return node.value + sum_of_nodes(node.left) + sum_of_nodes(node.right)
def subtract_summation(root):
  if root is None:
    return 0
  left_sum = sum_of_nodes(root.left)
  right_sum = sum_of_nodes(root.right)
  return abs(left_sum - right_sum)


#Driver Code
root=BTNode(71)
#Write other nodes by yourself from the given tree of Doc File


print(subtract_summation(root)) #This should print 111
# Out:
# 0

# %% [markdown]
# Bonus Task

# %%
def level_sum(root, key):
  #To Do
  # c=0
  # if root==None:
  #     return 0

  # else:

  #     if root.elm==key:
  #         c+=1

  #     c+=level_sum(root.left,key)
  #     c+=level_sum(root.right,key)

  #     return c

#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8


print(level_sum(root)) #This should print 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-2c92dd2ea84a> in <cell line: 37>()
#      35
#      36
# ---> 37 print(level_sum(root)) #This should print 4
#
# TypeError: level_sum() missing 1 required positional argument: 'key'
